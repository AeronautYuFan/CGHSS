# %%
from aflow import aflow

# %%
# Loads csv
flow = aflow('air_table.csv')

# %%
# Renders and saves 
flow.render_flow('Natural Disaster')
flow.save_flow('natural_disaster_flow_chart.jpeg', dpi=300)

# %%
# Renders and saves 
flow.render_flow('Act of War')
flow.save_flow('act_of_war_flow_chart.jpeg', dpi=300)
